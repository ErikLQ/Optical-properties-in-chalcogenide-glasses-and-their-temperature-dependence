# %%
import matplotlib.pyplot as plt
import numpy as np
import math 
import os, sys
import pandas as pd
import ipywidgets as widgets
from ipywidgets import interactive
from scipy import signal

# %%
wavelength_R, flir_R_PE = np.loadtxt('FLIR_data_2/sample_28_R_maskin1.SP', skiprows = 0, unpack = True)
wavelength_T, flir_T_PE = np.loadtxt('FLIR_data_2/sample_28_T_maskin1.SP', skiprows = 0, unpack = True)

wavenumber, flir_R_TENSOR = np.loadtxt('FLIR_data_2/sample_28_R_maskin2.DPT', skiprows = 0, unpack = True)
wavenumber, flir_T_TENSOR = np.loadtxt('FLIR_data_2/sample_28_T_maskin2.DPT', skiprows = 0, unpack = True)

wavenumber_R, flir_R_28 = np.loadtxt('FLIR_data/sample_28_R.DPT', skiprows = 0, unpack = True)
wavenumber_R, flir_R_35 = np.loadtxt('FLIR_data/sample_35_R.DPT', skiprows = 0, unpack = True)
wavenumber_R, flir_R_40 = np.loadtxt('FLIR_data/sample_40_R.DPT', skiprows = 0, unpack = True)
wavenumber_R, flir_R_45 = np.loadtxt('FLIR_data/sample_45_R.DPT', skiprows = 0, unpack = True)
wavenumber_R, flir_R_50 = np.loadtxt('FLIR_data/sample_50_R.DPT', skiprows = 0, unpack = True)
wavenumber_R, flir_R_60 = np.loadtxt('FLIR_data/sample_60_R.DPT', skiprows = 0, unpack = True)
wavenumber_R, flir_R_70 = np.loadtxt('FLIR_data/sample_70_R.DPT', skiprows = 0, unpack = True)
wavenumber_R, flir_R_28_heater = np.loadtxt('FLIR_data/sample-heater.DPT', skiprows = 0, unpack = True)

wavenumber_T, flir_T_28 = np.loadtxt('FLIR_data/sample_28_T.DPT', skiprows = 0, unpack = True)
wavenumber_T, flir_T_30 = np.loadtxt('FLIR_data/sample_30_T.DPT', skiprows = 0, unpack = True)
wavenumber_T, flir_T_35 = np.loadtxt('FLIR_data/sample_35_T.DPT', skiprows = 0, unpack = True)
wavenumber_T, flir_T_40 = np.loadtxt('FLIR_data/sample_40_T.DPT', skiprows = 0, unpack = True)
wavenumber_T, flir_T_45 = np.loadtxt('FLIR_data/sample_45_T.DPT', skiprows = 0, unpack = True)
wavenumber_T, flir_T_50 = np.loadtxt('FLIR_data/sample_50_T.DPT', skiprows = 0, unpack = True)
wavenumber_T, flir_T_55 = np.loadtxt('FLIR_data/sample_55_T.DPT', skiprows = 0, unpack = True)
wavenumber_T, flir_T_60 = np.loadtxt('FLIR_data/sample_60_T.DPT', skiprows = 0, unpack = True)
wavenumber_T, flir_T_65 = np.loadtxt('FLIR_data/sample_65_T.DPT', skiprows = 0, unpack = True)
wavenumber_T, flir_T_70 = np.loadtxt('FLIR_data/sample_70_T.DPT', skiprows = 0, unpack = True)

# %%
#Plot 1
plt.plot(1e4/wavenumber_T, flir_T_28, color = 'lightcoral', label = "28$^\circ$C")
plt.plot(1e4/wavenumber_T, flir_T_35, color = 'orangered', label = "35$^\circ$C")
plt.plot(1e4/wavenumber_T, flir_T_40, color = 'royalblue', label = "40$^\circ$C")
plt.plot(1e4/wavenumber_T, flir_T_45, color = 'green', label = "45$^\circ$C")
plt.plot(1e4/wavenumber_T, flir_T_50, color = 'limegreen', label = "50$^\circ$C")
plt.plot(1e4/wavenumber_T, flir_T_55, color = 'seagreen', label = "55$^\circ$C")
plt.plot(1e4/wavenumber_T, flir_T_60, color = 'teal', label = "60$^\circ$C")
plt.plot(1e4/wavenumber_T, flir_T_65, color = 'darkviolet', label = "65$^\circ$C")
plt.plot(1e4/wavenumber_T, flir_T_70, color = 'deepskyblue', label = "70$^\circ$C")
plt.legend(loc = 'best', frameon = False)
plt.xlim([2.5,15])
plt.ylim([0.55,0.85])
plt.title('Comparison plot of transmittance at several temperatures')
plt.xlabel('Wavelength [$\mu$m]')
plt.ylabel('Transmittance')
plt.grid()

plt.savefig('FLIR_figs/comparisionplot_T.pdf')
plt.show()

# %%
#Plot 2
plt.plot(1e4/wavenumber_R, flir_R_28, color = 'lightcoral', label = "28$^\circ$C")
plt.plot(1e4/wavenumber_R, flir_R_35, color = 'orangered', label = "35$^\circ$C")
plt.plot(1e4/wavenumber_R, flir_R_40, color = 'royalblue', label = "40$^\circ$C")
plt.plot(1e4/wavenumber_R, flir_R_45, color = 'green', label = "45$^\circ$C")
plt.plot(1e4/wavenumber_R, flir_R_50, color = 'limegreen', label = "50$^\circ$C")
plt.plot(1e4/wavenumber_R, flir_R_60, color = 'teal', label = "60$^\circ$C")
plt.plot(1e4/wavenumber_R, flir_R_70, color = 'deepskyblue', label = "70$^\circ$C")
plt.legend(loc = 'best', frameon = False)
plt.xlim([2.5,15])
plt.ylim([0.15,0.35])
plt.title('Comparison plot of reflectance at several temperatures')
plt.xlabel('Wavelength [$\mu$m]')
plt.ylabel('Reflectance')
plt.grid()

plt.savefig('FLIR_figs/comparisionplot_R.pdf')
plt.show()

# %%
#Plot 3
plt.plot(1e4/wavenumber,flir_T_TENSOR-0.02, color= 'red', label = 'T from Tensor +/- 0.02')
plt.plot(1e4/wavenumber_T, flir_T_28, color= 'blue', label = 'T from bruker')
plt.legend(loc = 'best', frameon=False)
plt.xlim([3,18])
plt.ylim([0,1])
plt.title('Comparison of measurements from Tensor and Bruker')
plt.xlabel('Wavelength [$\mu$m]')
plt.ylabel('Transmittance')
plt.grid()

plt.savefig('FLIR_figs/comparisionplot_tensorBruker.pdf')
plt.show()

# %%
#Plot 4

plt.plot(1e4/wavenumber,flir_T_TENSOR-0.02, color= 'red', label = 'T from Tensor +/- 0.02')
plt.plot(wavelength_R/1e3,flir_T_PE/100, color='darkorange', label = 'T from PE')
plt.plot(1e4/wavenumber,flir_R_TENSOR+0.02, color= 'blue', label = 'R from Tensor +/- 0.02')
plt.plot(wavelength_T/1e3,flir_R_PE/100, color='deepskyblue', label = 'R from PE')
plt.legend(loc = 'best', frameon=False)
plt.xlim([0.2,18])
plt.ylim([0,1])
plt.title('Comparison of measurements from PE and Tensor')
plt.xlabel('Wavelength [$\mu$m]')
plt.ylabel('Transmittance')
plt.grid()

plt.savefig('FLIR_figs/comparisionplot_tensorPE.pdf')
plt.show()

# %%
#Plot 5
wl= np.arange(0.3, 20, 0.5) #<---Wavelengths in interval
l= len(wl)
def N_mat(wl): #wavelength has to be in micron
    b1 = 3.1934
    b2 = 3.5854
    b3 = 2.2337
    c1 = 0.0
    c2= 0.1852
    c3= 3398.08
    return (1+ b1*wl**2/(wl**2-c1) + b2*wl**2/(wl**2-c2)+ b3*wl**2/(wl**2-c3))**0.5

def Rtot(R1,R2,T1, R1_prime,wl): #assuming no absorption
    return R1 + T1**2*R2/(1-R1_prime*R2)

def T_mat(n1,n2,wl):
    return n2/n1*(2*n1/(n1+n2))**2

def Rn_mat(n1, n2, wl):
    return ((n1-n2)/(n1+n2))**2

R1 = Rn_mat(1.0,N_mat(wl),wl)
R2 = Rn_mat(N_mat(wl),1.0,wl)
R1_prime = R2
T1 = T_mat(1.0, N_mat(wl), wl)

plt.plot(1e4/wavenumber,flir_R_TENSOR+0.02, color= 'blue', label = 'R from Tensor +/- 0.02')
plt.plot(wavelength_R/1e3,flir_R_PE/100, color='deepskyblue', label = 'R from PE')
plt.plot(wl,Rtot(R1,R2,T1, R1_prime, wl), color='black' ,label='R calculated (Schott)')
plt.legend(loc='best', fontsize= 12,frameon=False)
plt.ylim(0.2,0.6)
plt.xlim([1,15])
plt.title('Comparison of PE, Tensor and Schott (including internal reflection)')
plt.xlabel('Wavelength [$\mu$m]')
plt.ylabel('Reflectance')
plt.grid()

plt.savefig('FLIR_figs/comparision_tensor_pe_schott-internal.pdf')
plt.show()

# %%
#Plot 6
plt.plot(1e4/wavenumber,flir_R_TENSOR+0.02, color= 'blue', label = 'R from Tensor +/- 0.02')
plt.plot(wavelength_R/1e3,flir_R_PE/100, color='deepskyblue', label = 'R from PE')
plt.plot(wl,R1, color='black' ,label='R calculated (Schott)')
plt.legend(loc='best', fontsize= 12,frameon=False)
plt.ylim(0.2,0.6)
plt.xlim([1,15])
plt.title('Comparison of PE, Tensor and Schott (excluduing internal reflection)')
plt.xlabel('Wavelength [$\mu$m]')
plt.ylabel('Refletance')
plt.grid()

plt.savefig('FLIR_figs/comparision_tensor_pe_schott.pdf')
plt.show()

# %%
#Plot 7 CO2 absorption
plt.plot(1e4/wavenumber_R, flir_R_70, color = 'deepskyblue', label = "70$^\circ$C")
plt.legend(loc = 'best', frameon = False)
plt.xlim([2.5,15])
plt.ylim([0.15,0.35])
plt.title('CO$_2$ absorption')
plt.xlabel('Wavelength [$\mu$m]')
plt.ylabel('Reflectance')
plt.grid()

plt.annotate(
'CO$_2$ absorption', xy=(4.2, 0.16),xytext=(4.8, 0.16) ,
horizontalalignment="left",
arrowprops=dict(arrowstyle='->',lw=1)
)

plt.savefig('FLIR_figs/CO2abs.pdf')
plt.show()

# %%
#Plot 8
plt.plot(1e4/wavenumber_R, flir_R_28, color = 'lightcoral', label = "28$^\circ$C w/o heater")
plt.plot(1e4/wavenumber_R, flir_R_28_heater, color = "red" , label = "28$^\circ$C with heater")
plt.legend(loc = 'best', frameon = False)
plt.xlim([2.5,15])
plt.ylim([0.15,0.60])
plt.title('Comparison plot of reflectance with or w/o resistive heater')
plt.xlabel('Wavelength [$\mu$m]')
plt.ylabel('Reflectance')
plt.grid()

plt.savefig('FLIR_figs/comparisionplot_R_heater.pdf')
plt.show()

# %% [markdown]
# First we define a function that calculates the refractive index as a funcion of the parameters **b1**, **b2**, **b3**, **c1**, **c2**, and **c3**.

# %%
def N_flir(wl,b1,b2,b3,c1,c2,c3): #wavelenght has to be in micron
   return (1+ b1*wl**2/(wl**2-c1) + b2*wl**2/(wl**2-c2)+ b3*wl**2/(wl**2-c3))**0.5
def Rn_mat(n1, n2, wl):
    return ((n1-n2)/(n1+n2))**2
def T_mat(n1,n2,wl):
    return n2/n1*(2*n1/(n1+n2))**2

# %% [markdown]
# Function that takes  the parameters **b1**, **b2**, **b3**, **c1**, **c2**, and **c3** as input, as well as the wavelength range **wl** as input and returns the reflectance

# %%
def Rtot(wl,b1,b2,b3,c1,c2,c3): 
    
    N_mat = N_flir(wl,b1,b2,b3,c1,c2,c3)
    R1 = Rn_mat(1.0,N_mat,wl)
    R2 = Rn_mat(N_mat,1.0,wl)
    R1_prime = R2
    T1 = T_mat(1.0, N_mat, wl)
    return R1 + T1**2*R2/(1-R1_prime*R2)

# %% [markdown]
# Define the wavelength range in microns:

# %%
wl= np.arange(0.8, 25, 0.5) #wavelength range in microns

# %% [markdown]
# Plot the data (use sliders for possible values of the constants)

# %%
def Rtot_2(b1,b2,b3,c1,c2,c3): 
    wl= np.arange(2, 25, 0.5)
    N_mat = N_flir(wl,b1,b2,b3,c1,c2,c3)
    R1 = Rn_mat(1.0,N_mat,wl)
    R2 = Rn_mat(N_mat,1.0,wl)
    R1_prime = R2
    T1 = T_mat(1.0, N_mat, wl)
    Result = R1 + T1**2*R2/(1-R1_prime*R2)
    plt.plot(wl,Result, label='R calculated')
    plt.plot(1e4/wavenumber_R,flir_R_28, label = '28$^\circ$C')
    plt.plot(1e4/wavenumber_R,flir_R_70, label = '70$^\circ$C')
    plt.xlabel("Wavelength ($\mu$m)")
    plt.ylabel("R")
    plt.legend(loc='best', fontsize= 12,frameon=False)
    plt.ylim(0,1.0)
    plt.xlim([0.3,15])
    plt.grid()
    plt.show()
    
interactive_plot = interactive(Rtot_2, b1=(2.5,3.5, 0.1), b2=(3.0,4.0, 0.1),b3=(2.0,3.0, 0.1),c1=(0.0,1.0, 0.1),c2=(0.0,1.0, 0.1), c3=(2000.0,4000.0, 100.0))
output = interactive_plot.children[-1]
interactive_plot
# Out:
# interactive(children=(FloatSlider(value=3.0, description='b1', max=3.5, min=2.5), FloatSlider(value=3.5, descr…
